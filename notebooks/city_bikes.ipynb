# %% [markdown]
# # CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
import requests

import json

# %%
url = "https://api.citybik.es/v2/networks/toronto"
response = requests.get(url)


data = response.json()

# Save JSON response to a file
with open('network_info.json', 'w') as f:
    json.dump(data, f)

# Load the saved JSON file
with open('network_info.json') as f:
    network_info = json.load(f)

print(network_info)
# Out:
# {'network': {'company': ['Motivate International, Inc.', 'PBSC Urban Solutions'], 'gbfs_href': 'https://tor.publicbikesystem.net/ube/gbfs/v1/', 'href': '/v2/networks/bixi-toronto', 'id': 'bixi-toronto', 'location': {'city': 'Toronto, ON', 'country': 'CA', 'latitude': 43.653226, 'longitude': -79.3831843}, 'name': 'Bike Share Toronto', 'stations': [{'empty_slots': 15, 'extra': {'address': 'Queen St E / Woodward Ave', 'altitude': 0.0, 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1688333056, 'normal_bikes': 4, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'renting': 1, 'returning': 1, 'slots': 19, 'uid': '7303'}, 'free_bikes': 4, 'id': 'fb337bbed72e2be090071e199899b2be', 'latitude': 43.665269, 'longitude': -79.319796, 'name': 'Queen St E / Woodward Ave', 'timestamp': '2023-07-02T21:24:54.234000Z'}, {'empty_slots': 8, 'extra': {'address': 'Primrose Ave / Davenport Rd', 'altitude': 0.0, 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1688332913, 'normal_bikes': 7, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'renting': 1, 'returning': 1, 'slots': 15, 'uid': '7301'}, 'free_bikes': 7, 'id': '4ff88d5880e71aa40d34cfe5d09b0ca7', 'latitude': 43.67142, 'longitude': -79.445947, 'name': 'Primrose Ave / Davenport Rd', 'timestamp': '2023-07-02T21:24:54.235000Z'}, {'empty_slots': 23, 'extra': {'address': 'Queen St. E / Rhodes Ave.', 'altitude': 0.0, 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1688332916, 'normal_bikes': 0, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'renting': 1, 'returning': 1, 'slots': 23, 'uid': '7309'}, 'free_bikes': 0, 'id': 'a09c67c0b419654d907c9134b108e328', 'latitude': 43.666224, 'longitude': -79.317693, 'name': 'Queen St. E / Rhodes Ave.', 'timestamp': '2023-07-02T21:24:54.236000Z'}, {'empty_slots': 22, 'extra': {'address': 'Bond St / Queen St E', 'altitude': 0.0, 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1688332999, 'normal_bikes': 2, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'renting': 1, 'returning': 1, 'slots': 25, 'uid': '7045'}, 'free_bikes': 2, 'id': 'd6a9daee68070a8b106cfb598d81308c', 'latitude': 43.653236, 'longitude': -79.376716, 'name': 'Bond St / Queen St E', 'timestamp': '2023-07-02T21:24:54.240000Z'}, {'empty_slots': 11, 'extra': {'address': 'Church St / Alexander St', 'altitude': 0.0, 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1688332944, 'normal_bikes': 4, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'renting': 1, 'returning': 1, 'slots': 15, 'uid': '7044'}, 'free_bikes': 4, 'id': '8f8af40d9388c8a3962559e8681d3db7', 'latitude': 43.663722, 'longitude': -79.380288, 'name': 'Church St / Alexander St', 'timestamp': '2023-07-02T21:24:54.241000Z'}, {'empty_slots': 8, 'extra': {'address': 'University Ave / Gerrard St W', 'altitude': 0.0, 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1688332956, 'normal_bikes': 17, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'renting': 1, 'returning': 1, 'slots': 25, 'uid': '7047'}, 'free_bikes': 17, 'id': '5a441560e262305d1934fb3ada5a9517', 'latitude': 43.657763, 'longitude': -79.389165, 'name': 'University Ave / Gerrard St W (East Side)', 'timestamp': '2023-07-02T21:24:54.242000Z'}, {'empty_slots': 12, 'extra': {'address': 'Edward St / Yonge St', 'altitude': None, 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1688332833, 'normal_bikes': 11, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'renting': 1, 'returning': 1, 'slots': 23, 'uid': '7041'}, 'free_bikes': 11, 'id': '18ea490ab3ca4d10e2927308416edbef', 'latitude': 43.656729, 'longitude': -79.382736, 'name': 'Edward St / Yonge St', 'timestamp': '2023-07-02T21:24:54.243000Z'}, {'empty_slots': 14, 'extra': {'address': 'Euclid Ave / Bloor St W', 'altitude': 0.0, 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1688332789, 'normal_ ...

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
import pprint
pprint.pprint(network_info)
# Out:
# {'network': {'company': ['Motivate International, Inc.',
#                          'PBSC Urban Solutions'],
#              'gbfs_href': 'https://tor.publicbikesystem.net/ube/gbfs/v1/',
#              'href': '/v2/networks/bixi-toronto',
#              'id': 'bixi-toronto',
#              'location': {'city': 'Toronto, ON',
#                           'country': 'CA',
#                           'latitude': 43.653226,
#                           'longitude': -79.3831843},
#              'name': 'Bike Share Toronto',
#              'stations': [{'empty_slots': 15,
#                            'extra': {'address': 'Queen St E / Woodward Ave',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688333056,
#                                      'normal_bikes': 4,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7303'},
#                            'free_bikes': 4,
#                            'id': 'fb337bbed72e2be090071e199899b2be',
#                            'latitude': 43.665269,
#                            'longitude': -79.319796,
#                            'name': 'Queen St E / Woodward Ave',
#                            'timestamp': '2023-07-02T21:24:54.234000Z'},
#                           {'empty_slots': 8,
#                            'extra': {'address': 'Primrose Ave / Davenport Rd',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332913,
#                                      'normal_bikes': 7,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7301'},
#                            'free_bikes': 7,
#                            'id': '4ff88d5880e71aa40d34cfe5d09b0ca7',
#                            'latitude': 43.67142,
#                            'longitude': -79.445947,
#                            'name': 'Primrose Ave / Davenport Rd',
#                            'timestamp': '2023-07-02T21:24:54.235000Z'},
#                           {'empty_slots': 23,
#                            'extra': {'address': 'Queen St. E / Rhodes Ave.',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332916,
#                                      'normal_bikes': 0,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 23,
#                                      'uid': '7309'},
#                            'free_bikes': 0,
#                            'id': 'a09c67c0b419654d907c9134b108e328',
#                            'latitude': 43.666224,
#                            'longitude': -79.317693,
#                            'name': 'Queen St. E / Rhodes Ave.',
#                            'timestamp': '2023-07-02T21:24:54.236000Z'},
#                           {'empty_slots': 22,
#                            'extra': {'address': 'Bond St / Queen St E',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332999,
#                                      'normal_bikes': 2,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 25,
#                                      'uid': '7045'},
#                            'free_bikes': 2,
#                            'id': 'd6a9daee68070a8b106cfb598d81308c',
#                            'latitude': 43.653236,
#                            'longitude': -79.376716,
#                            'name': 'Bond St / Queen St E',
#                            'timestamp': '2023-07-02T21:24:54.240000Z'},
#                           {'empty_slots': 11,
#                            'extra': {'address': 'Church St / Alexander St',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332944,
#                                      'normal_bikes': 4,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7044'},
#                            'free_bikes': 4,
#                            'id': '8f8af40d9388c8a3962559e8681d3db7',
#                            'latitude': 43.663722,
#                            'longitude': -79.380288,
#                            'name': 'Church St / Alexander St',
#                            'timestamp': '2023-07-02T21:24:54.241000Z'},
#                           {'empty_slots': 8,
#                            'extra': {'address': 'University Ave / Gerrard St W',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332956,
#                                      'normal_bikes': 17,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 25,
#                                      'uid': '7047'},
#                            'free_bikes': 17,
#                            'id': '5a441560e262305d1934fb3ada5a9517',
#                            'latitude': 43.657763,
#                            'longitude': -79.389165,
#                            'name': 'University Ave / Gerrard St W (East Side)',
#                            'timestamp': '2023-07-02T21:24:54.242000Z'},
#                           {'empty_slots': 12,
#                            'extra': {'address': 'Edward St / Yonge St',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332833,
#                                      'normal_bikes': 11,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 23,
#                                      'uid': '7041'},
#                            'free_bikes': 11,
#                            'id': '18ea490ab3ca4d10e2927308416edbef',
#                            'latitude': 43.656729,
#                            'longitude': -79.382736,
#                            'name': 'Edward St / Yonge St',
#                            'timestamp': '2023-07-02T21:24:54.243000Z'},
#                           {'empty_slots': 14,
#                            'extra': {'address': 'Euclid Ave / Bloor St W',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332789,
#                                      'normal_bikes': 5,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7040'},
#                            'free_bikes': 5,
#                            'id': 'b7850948607474362d3728f19a77fdff',
#                            'latitude': 43.664467,
#                            'longitude': -79.414783,
#                            'name': 'Euclid Ave / Bloor St W',
#                            'timestamp': '2023-07-02T21:24:54.244000Z'},
#                           {'empty_slots': 8,
#                            'extra': {'address': 'Yonge St / Aylmer Ave',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688333013,
#                                      'normal_bikes': 7,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7128'},
#                            'free_bikes': 7,
#                            'id': '7ffd06e0207f80fe1ff6b5ae0bb0544c',
#                            'latitude': 43.675492,
#                            'longitude': -79.388858,
#                            'name': 'Yonge St / Aylmer Ave',
#                            'timestamp': '2023-07-02T21:24:54.244000Z'},
#                           {'empty_slots': 5,
#                            'extra': {'address': 'Davenport Rd / Avenue Rd',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332922,
#                                      'normal_bikes': 5,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 11,
#                                      'uid': '7129'},
#                            'free_bikes': 5,
#                            'id': '17fadbdc5848036c8485099bbf517294',
#                            'latitude': 43.674991,
#                            'longitude': -79.396273,
#                            'name': 'Davenport Rd / Avenue Rd',
#                            'timestamp': '2023-07-02T21:24:54.245000Z'},
#                           {'empty_slots': 13,
#                            'extra': {'address': 'Yonge St / Yorkville Ave',
#                                      'altitude': 0.0,
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332867,
#                                      'normal_bikes': 1,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 17,
#                                      'uid': '7126'},
#                            'free_bikes': 2,
#                            'id': '843dcb87ce2ddb002d2b2900a5418355',
#                            'latitude': 43.671944,
#                            'longitude': -79.387778,
#                            'name': 'Yonge St / Yorkville Ave',
#                            'timestamp': '2023-07-02T21:24:54.246000Z'},
#                           {'empty_slots': 16,
#                            'extra': {'address': 'Dundas St E / Broadview Ave',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688333000,
#                                      'normal_bikes': 2,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7124'},
#                            'free_bikes': 2,
#                            'id': '438406694750984faa317bc6b1f3f909',
#                            'latitude': 43.662365,
#                            'longitude': -79.351104,
#                            'name': 'Dundas St E / Broadview Ave',
#                            'timestamp': '2023-07-02T21:24:54.247000Z'},
#                           {'empty_slots': 30,
#                            'extra': {'address': 'Front St W / Yonge St (Hockey '
#                                                 'Hall of Fame)',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332925,
#                                      'normal_bikes': 17,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 47,
#                                      'uid': '7048'},
#                            'free_bikes': 17,
#                            'id': '41c3e6d3bf3bd993e7d56e22084ab5ee',
#                            'latitude': 43.646144,
#                            'longitude': -79.377962,
#                            'name': 'Front St W / Yonge St (Hockey Hall of '
#                                    'Fame)',
#                            'timestamp': '2023-07-02T21:24:54.249000Z'},
#                           {'empty_slots': 8,
#                            'extra': {'address': 'Gerrard St E / River St',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688333028,
#                                      'normal_bikes': 2,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 11,
#                                      'uid': '7120'},
#                            'free_bikes': 2,
#                            'id': 'c95712a6fe0babf73cb9da2c05889749',
#                            'latitude': 43.663993,
#                            'longitude': -79.358534,
#                            'name': 'Gerrard St E / River St',
#                            'timestamp': '2023-07-02T21:24:54.249000Z'},
#                           {'empty_slots': 13,
#                            'extra': {'address': 'Jarvis St / Dundas St E',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332956,
#                                      'normal_bikes': 14,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 27,
#                                      'uid': '7121'},
#                            'free_bikes': 14,
#                            'id': '2aedc79960408d746f43fb1d91bf7030',
#                            'latitude': 43.657266,
#                            'longitude': -79.374756,
#                            'name': 'Jarvis St / Dundas St E',
#                            'timestamp': '2023-07-02T21:24:54.250000Z'},
#                           {'empty_slots': 5,
#                            'extra': {'address': 'Logan Av / Gerrard St E',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332943,
#                                      'normal_bikes': 10,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7346'},
#                            'free_bikes': 10,
#                            'id': '784016bbba7f7be920647e7f8ec00251',
#                            'latitude': 43.6672144,
#                            'longitude': -79.3452697,
#                            'name': 'Logan Av / Gerrard St E',
#                            'timestamp': '2023-07-02T21:24:54.265000Z'},
#                           {'empty_slots': 9,
#                            'extra': {'address': 'Regal Rd / Dufferin St',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332860,
#                                      'normal_bikes': 6,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7347'},
#                            'free_bikes': 6,
#                            'id': '77f9f2420581968255251d9f26c78024',
#                            'latitude': 43.673939,
#                            'longitude': -79.441159,
#                            'name': 'Regal Rd / Dufferin St',
#                            'timestamp': '2023-07-02T21:24:54.268000Z'},
#                           {'empty_slots': 3,
#                            'extra': {'address': 'Morse St / Eastern Ave',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332903,
#                                      'normal_bikes': 7,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 11,
#                                      'uid': '7342'},
#                            'free_bikes': 7,
#                            'id': '7461a94289f2956b380e5b7684b56a1e',
#                            'latitude': 43.657991,
#                            'longitude': -79.340075,
#                            'name': 'Morse St / Eastern Ave',
#                            'timestamp': '2023-07-02T21:24:54.270000Z'},
#                           {'empty_slots': 16,
#                            'extra': {'address': 'Alton Ave / Dundas St E '
#                                                 '(Greenwood Park)',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332845,
#                                      'normal_bikes': 5,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 22,
#                                      'uid': '7343'},
#                            'free_bikes': 5,
#                            'id': '69dc0257a4d3a1dcd5af06dc3b4eed8c',
#                            'latitude': 43.66745,
#                            'longitude': -79.329408,
#                            'name': 'Alton Ave / Dundas St E (Greenwood Park)',
#                            'timestamp': '2023-07-02T21:24:54.271000Z'},
#                           {'empty_slots': 8,
#                            'extra': {'address': 'Blake St / Boultbee Ave',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332842,
#                                      'normal_bikes': 7,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7340'},
#                            'free_bikes': 7,
#                            'id': '365a0f49bf1c9b42c35b531688b9fed9',
#                            'latitude': 43.672453,
#                            'longitude': -79.338259,
#                            'name': 'Blake St / Boultbee Ave',
#                            'timestamp': '2023-07-02T21:24:54.271000Z'},
#                           {'empty_slots': 0,
#                            'extra': {'address': 'Eastern Ave / Winnifred Ave',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688333056,
#                                      'normal_bikes': 14,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 14,
#                                      'uid': '7341'},
#                            'free_bikes': 14,
#                            'id': '49021f20833894e3dbfaea4fb6e7a9dc',
#                            'latitude': 43.6592088,
#                            'longitude': -79.3348396,
#                            'name': 'Eastern Ave / Winnifred Ave',
#                            'timestamp': '2023-07-02T21:24:54.272000Z'},
#                           {'empty_slots': 13,
#                            'extra': {'address': 'Gamble Ave / Broadview Ave',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332792,
#                                      'normal_bikes': 10,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 23,
#                                      'uid': '7349'},
#                            'free_bikes': 10,
#                            'id': '3910976dfd5888140602a42b14637022',
#                            'latitude': 43.689211,
#                            'longitude': -79.35438,
#                            'name': 'Gamble Ave / Broadview Ave',
#                            'timestamp': '2023-07-02T21:24:54.273000Z'},
#                           {'empty_slots': 5,
#                            'extra': {'address': '111 Bond St (North of Dundas '
#                                                 'St E)',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332923,
#                                      'normal_bikes': 11,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 16,
#                                      'uid': '7268'},
#                            'free_bikes': 11,
#                            'id': '1fe2e0ad1678ffaf965b10e03a08aaf2',
#                            'latitude': 43.656927,
#                            'longitude': -79.378497,
#                            'name': '111 Bond St (North of Dundas St E)  - '
#                                    'SMART',
#                            'timestamp': '2023-07-02T21:24:54.275000Z'},
#                           {'empty_slots': 9,
#                            'extra': {'address': 'Dundas St E / Pembroke St',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332843,
#                                      'normal_bikes': 7,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 16,
#                                      'uid': '7267'},
#                            'free_bikes': 7,
#                            'id': 'e565aef96d6d5fce5279ef6f24b9ce69',
#                            'latitude': 43.658295,
#                            'longitude': -79.372346,
#                            'name': 'Dundas St E / Pembroke St - SMART',
#                            'timestamp': '2023-07-02T21:24:54.278000Z'},
#                           {'empty_slots': 11,
#                            'extra': {'address': 'Victoria Park Subway Station',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332816,
#                                      'normal_bikes': 9,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 20,
#                                      'uid': '7266'},
#                            'free_bikes': 9,
#                            'id': 'c765943cac057b6cac0946eff428bf5b',
#                            'latitude': 43.6940155,
#                            'longitude': -79.2889842,
#                            'name': 'Victoria Park Subway Station - SMART',
#                            'timestamp': '2023-07-02T21:24:54.278000Z'},
#                           {'empty_slots': 16,
#                            'extra': {'address': 'Wychwood Ave / Benson Ave',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332817,
#                                      'normal_bikes': 0,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 16,
#                                      'uid': '7262'},
#                            'free_bikes': 0,
#                            'id': 'e0dec8b8f5ed285bfbd952bb253084f4',
#                            'latitude': 43.6809164,
#                            'longitude': -79.4229684,
#                            'name': 'Wychwood Ave / Benson Ave - SMART',
#                            'timestamp': '2023-07-02T21:24:54.281000Z'},
#                           {'empty_slots': 5,
#                            'extra': {'address': 'Lawton Blvd / Yonge St',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332807,
#                                      'normal_bikes': 10,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7379'},
#                            'free_bikes': 10,
#                            'id': '5ee5f79fc51737623d425310eb0bf02b',
#                            'latitude': 43.6910667,
#                            'longitude': -79.39535,
#                            'name': 'Lawton Blvd / Yonge St',
#                            'timestamp': '2023-07-02T21:24:54.292000Z'},
#                           {'empty_slots': 15,
#                            'extra': {'address': 'Yonge St / Davisville Ave',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332831,
#                                      'normal_bikes': 0,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7378'},
#                            'free_bikes': 0,
#                            'id': '0daa4477ec313c30dc3036f4bd45e0ba',
#                            'latitude': 43.6975969,
#                            'longitude': -79.39654,
#                            'name': 'Yonge St / Davisville Ave',
#                            'timestamp': '2023-07-02T21:24:54.790000Z'},
#                           {'empty_slots': 24,
#                            'extra': {'address': 'Fort York  Blvd / Capreol Ct',
#                                      'altitude': 0.0,
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688333033,
#                                      'normal_bikes': 8,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 35,
#                                      'uid': '7000'},
#                            'free_bikes': 9,
#                            'id': 'e2911ec2b832c350dad0a8831a30d273',
#                            'latitude': 43.639832,
#                            'longitude': -79.395954,
#                            'name': 'Fort York  Blvd / Capreol Ct',
#                            'timestamp': '2023-07-02T21:24:54.296000Z'},
#                           {'empty_slots': 1,
#                            'extra': {'address': 'Madison Ave / Bloor St W',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332937,
#                                      'normal_bikes': 14,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7003'},
#                            'free_bikes': 14,
#                            'id': '83af92756a52874ce9bade85f065f4d1',
#                            'latitude': 43.667158,
#                            'longitude': -79.402761,
#                            'name': 'Madison Ave / Bloor St W',
#                            'timestamp': '2023-07-02T21:24:54.296000Z'},
#                           {'empty_slots': 14,
#                            'extra': {'address': 'St. George St / Bloor St W',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332993,
#                                      'normal_bikes': 5,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7002'},
#                            'free_bikes': 5,
#                            'id': '57ef343f4e12ae497e29c3693d922197',
#                            'latitude': 43.667333,
#                            'longitude': -79.399429,
#                            'name': 'St. George St / Bloor St W',
#                            'timestamp': '2023-07-02T21:24:54.297000Z'},
#                           {'empty_slots': 4,
#                            'extra': {'address': 'King St W / York St',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332938,
#                                      'normal_bikes': 19,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 23,
#                                      'uid': '7005'},
#                            'free_bikes': 19,
#                            'id': 'a0100ff8f210b72706e06b4c31a329fe',
#                            'latitude': 43.6480008,
#                            'longitude': -79.383177,
#                            'name': 'King St W / York St',
#                            'timestamp': '2023-07-02T21:24:54.298000Z'},
#                           {'empty_slots': 4,
#                            'extra': {'address': 'University Ave / Elm St',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332964,
#                                      'normal_bikes': 7,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 11,
#                                      'uid': '7004'},
#                            'free_bikes': 7,
#                            'id': '32cb4912f6d3269c070a43e658dea18d',
#                            'latitude': 43.656518,
#                            'longitude': -79.389099,
#                            'name': 'University Ave / Elm St',
#                            'timestamp': '2023-07-02T21:24:54.298000Z'},
#                           {'empty_slots': 16,
#                            'extra': {'address': 'Rosehill Ave / Avoca Ave',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688333011,
#                                      'normal_bikes': 0,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 16,
#                                      'uid': '7279'},
#                            'free_bikes': 0,
#                            'id': '75b9fc3e9bf42a5d26fa1393d9ce72ed',
#                            'latitude': 43.687999,
#                            'longitude': -79.38906,
#                            'name': 'Rosehill Ave / Avoca Ave - SMART',
#                            'timestamp': '2023-07-02T21:24:54.301000Z'},
#                           {'empty_slots': 7,
#                            'extra': {'address': 'Bloor St W / Dundas St W',
#                                      'altitude': 0.0,
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332952,
#                                      'normal_bikes': 7,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7174'},
#                            'free_bikes': 8,
#                            'id': 'd3e1a4057d9bf7c31c216017a0f1989b',
#                            'latitude': 43.6563889,
#                            'longitude': -79.45166666666667,
#                            'name': 'Bloor St W / Dundas St W',
#                            'timestamp': '2023-07-02T21:24:54.304000Z'},
#                           {'empty_slots': 7,
#                            'extra': {'address': 'Bathurst St / Fort York Blvd',
#                                      'altitude': 0.0,
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332979,
#                                      'normal_bikes': 11,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7176'},
#                            'free_bikes': 12,
#                            'id': '8a4d335d5540e0c2132ffdb1def165f6',
#                            'latitude': 43.639179,
#                            'longitude': -79.399595,
#                            'name': 'Bathurst St / Fort York Blvd',
#                            'timestamp': '2023-07-02T21:24:54.304000Z'},
#                           {'empty_slots': 9,
#                            'extra': {'address': 'Spadina Ave / Willcocks St',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332876,
#                                      'normal_bikes': 5,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7170'},
#                            'free_bikes': 5,
#                            'id': '359ce82fbe9d1e9e9962321e62f6066f',
#                            'latitude': 43.6616667,
#                            'longitude': -79.40138888888889,
#                            'name': 'Spadina Ave / Willcocks St',
#                            'timestamp': '2023-07-02T21:24:54.306000Z'},
#                           {'empty_slots': 10,
#                            'extra': {'address': 'Cariboo St / Rail Path',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332933,
#                                      'normal_bikes': 9,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7173'},
#                            'free_bikes': 9,
#                            'id': '4077bf05c083f50d09a52487fd234193',
# ...
#                            'free_bikes': 6,
#                            'id': 'dbf9d3fb9932d05d7ddda51acd4d26b0',
#                            'latitude': 43.661324,
#                            'longitude': -79.449534,
#                            'name': 'Wallace Ave / Symington Ave - SMART',
#                            'timestamp': '2023-07-02T21:24:54.276000Z'},
#                           {'empty_slots': 21,
#                            'extra': {'address': 'Yonge / Wellesley',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332965,
#                                      'normal_bikes': 1,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': 'M4Y 1G7',
#                                      'renting': 0,
#                                      'returning': 0,
#                                      'slots': 23,
#                                      'uid': '7001'},
#                            'free_bikes': 0,
#                            'id': 'c89b262c82b9b2107a954987d36ad4a3',
#                            'latitude': 43.66496415990742,
#                            'longitude': -79.38355031526893,
#                            'name': 'Wellesley Station Green P',
#                            'timestamp': '2023-07-02T21:24:54.295000Z'},
#                           {'empty_slots': 2,
#                            'extra': {'address': 'York St / Harbour St (Love '
#                                                 'Park)',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332619,
#                                      'normal_bikes': 13,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': 'M5J',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7794'},
#                            'free_bikes': 13,
#                            'id': '813af609ddd87595d5352942579a73a9',
#                            'latitude': 43.640741,
#                            'longitude': -79.3798521,
#                            'name': 'York St / Harbour St (Love Park)',
#                            'timestamp': '2023-07-02T21:24:54.613000Z'},
#                           {'empty_slots': 4,
#                            'extra': {'address': 'Sherbourne St / Carlton St '
#                                                 '(Allan Gardens)',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332995,
#                                      'normal_bikes': 12,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 17,
#                                      'uid': '7014'},
#                            'free_bikes': 12,
#                            'id': '7fac6bfdffa0a7b4ff8a3f1ebd78da81',
#                            'latitude': 43.663102,
#                            'longitude': -79.373181,
#                            'name': 'Sherbourne St / Carlton St (Allan Gardens)',
#                            'timestamp': '2023-07-02T21:24:54.827000Z'},
#                           {'empty_slots': 16,
#                            'extra': {'address': 'Ontario Place Blvd / Lake '
#                                                 'Shore Blvd W',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332998,
#                                      'normal_bikes': 10,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 27,
#                                      'uid': '7171'},
#                            'free_bikes': 10,
#                            'id': 'f91f2493c8cca75e7c70987c8d0a516c',
#                            'latitude': 43.6322445,
#                            'longitude': -79.4108105,
#                            'name': 'Ontario Place Blvd / Lake Shore Blvd W',
#                            'timestamp': '2023-07-02T21:24:54.305000Z'},
#                           {'empty_slots': 12,
#                            'extra': {'address': 'Simcoe St / Dundas St W',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688333054,
#                                      'normal_bikes': 4,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': 'M5G 1W7',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 20,
#                                      'uid': '7668'},
#                            'free_bikes': 4,
#                            'id': '40e171b076eee2cc9b8405f394f0ace7',
#                            'latitude': 43.655103,
#                            'longitude': -79.389295,
#                            'name': 'Simcoe St / Dundas St W - SMART',
#                            'timestamp': '2023-07-02T21:24:54.795000Z'},
#                           {'empty_slots': 11,
#                            'extra': {'address': 'College St / Markham St',
#                                      'altitude': 0.0,
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332887,
#                                      'normal_bikes': 7,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7199'},
#                            'free_bikes': 8,
#                            'id': '8362e07e9e4d9c67eb283cae15684c8e',
#                            'latitude': 43.6563888888889,
#                            'longitude': -79.4091666666667,
#                            'name': 'College St / Markham St',
#                            'timestamp': '2023-07-02T21:24:54.505000Z'},
#                           {'empty_slots': 11,
#                            'extra': {'address': 'Dundas St W / Crawford St',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688333029,
#                                      'normal_bikes': 11,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 23,
#                                      'uid': '7207'},
#                            'free_bikes': 11,
#                            'id': '9d62413fcaba8ee2d11737b28e8651be',
#                            'latitude': 43.649722,
#                            'longitude': -79.416944,
#                            'name': 'Dundas St W / Crawford St',
#                            'timestamp': '2023-07-02T21:24:54.671000Z'},
#                           {'empty_slots': 3,
#                            'extra': {'address': 'Sunnyside - Gus Ryder Pool',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688333032,
#                                      'normal_bikes': 24,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 27,
#                                      'uid': '7222'},
#                            'free_bikes': 24,
#                            'id': '71ecba080a7e19ebfb8dcde4964a5277',
#                            'latitude': 43.637894,
#                            'longitude': -79.454823,
#                            'name': 'Sunnyside - Gus Ryder Pool',
#                            'timestamp': '2023-07-02T21:24:54.328000Z'},
#                           {'empty_slots': 22,
#                            'extra': {'address': 'High Park - West Rd',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332963,
#                                      'normal_bikes': 1,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': '1324',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 23,
#                                      'uid': '7086'},
#                            'free_bikes': 1,
#                            'id': '90255da65a5396af7e18b556f1d3e618',
#                            'latitude': 43.6525077,
#                            'longitude': -79.4654233,
#                            'name': 'High Park - West Rd',
#                            'timestamp': '2023-07-02T21:24:54.532000Z'},
#                           {'empty_slots': 23,
#                            'extra': {'address': 'Bloor St W / High Park Ave '
#                                                 '(High Park)',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332934,
#                                      'normal_bikes': 0,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 23,
#                                      'uid': '7224'},
#                            'free_bikes': 0,
#                            'id': 'ba4fc8dd224feedb2762d341bf58916f',
#                            'latitude': 43.6535269,
#                            'longitude': -79.4650569,
#                            'name': 'Bloor St W / High Park Ave (High Park)',
#                            'timestamp': '2023-07-02T21:24:54.330000Z'},
#                           {'empty_slots': 13,
#                            'extra': {'address': 'Front St E / Cherry St',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332976,
#                                      'normal_bikes': 2,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7108'},
#                            'free_bikes': 2,
#                            'id': '15e76731635f7e3ac4484228bc8f60ad',
#                            'latitude': 43.652686,
#                            'longitude': -79.358395,
#                            'name': 'Front St E / Cherry St',
#                            'timestamp': '2023-07-02T21:24:54.463000Z'},
#                           {'empty_slots': 1,
#                            'extra': {'address': 'Barbara Hall Park',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1688332844,
#                                      'normal_bikes': 10,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 12,
#                                      'uid': '7795'},
#                            'free_bikes': 10,
#                            'id': '25b1225382e6b213b935daffe25fbfff',
#                            'latitude': 43.666850777484896,
#                            'longitude': -79.38114574756837,
#                            'name': '519 Church St  - SMART',
#                            'timestamp': '2023-07-02T21:24:54.611000Z'}]}}

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
import pandas as pd
import json

# Load JSON data
url = "https://api.citybik.es/v2/networks/toronto"
response = requests.get(url)


network_info= response.json()
# Extracting station information
stations = network_info['network']['stations']

# Initialize empty lists to store station data
available_bikes_list = []
latitude_list = []
longitude_list = []
station_id_list =[]

# Iterate over stations and extract desired information
for station in stations:
    available_bikes = station['free_bikes']
    latitude = station['latitude']
    longitude = station['longitude']
    station_id= station['id']
    
    # Append data to respective lists
    available_bikes_list.append(available_bikes)
    latitude_list.append(latitude)
    longitude_list.append(longitude)
    station_id_list.append(station_id)

# Create a temporary dictionary with extracted data
temporary_dict = {'available_bikes': available_bikes_list, 'latitude': latitude_list, 'longitude': longitude_list, 'station_id': station_id_list}

# Create DataFrame from the temporary dictionary
df = pd.DataFrame(temporary_dict)

#Create a column 'LL' with both lat and long to enable looping thru the station coordinates
df['LL'] = df['latitude'].astype(str) + ',' + df['longitude'].astype(str)

# %%
df
# Out:
#      available_bikes   latitude  longitude                        station_id  \
# 0                  3  43.665269 -79.319796  fb337bbed72e2be090071e199899b2be
# 1                  7  43.671420 -79.445947  4ff88d5880e71aa40d34cfe5d09b0ca7
# 2                  2  43.666224 -79.317693  a09c67c0b419654d907c9134b108e328
# 3                  1  43.653236 -79.376716  d6a9daee68070a8b106cfb598d81308c
# 4                  5  43.663722 -79.380288  8f8af40d9388c8a3962559e8681d3db7
# ..               ...        ...        ...                               ...
# 664               24  43.637894 -79.454823  71ecba080a7e19ebfb8dcde4964a5277
# 665                2  43.652508 -79.465423  90255da65a5396af7e18b556f1d3e618
# 666                0  43.653527 -79.465057  ba4fc8dd224feedb2762d341bf58916f
# 667                3  43.652686 -79.358395  15e76731635f7e3ac4484228bc8f60ad
# 668               10  43.666851 -79.381146  25b1225382e6b213b935daffe25fbfff
#
#                                         LL
# 0                     43.665269,-79.319796
# 1                      43.67142,-79.445947
# 2                     43.666224,-79.317693
# 3                     43.653236,-79.376716
# 4                     43.663722,-79.380288
# ..                                     ...
# 664                   43.637894,-79.454823
# 665                 43.6525077,-79.4654233
# 666                 43.6535269,-79.4650569
# 667                   43.652686,-79.358395
# 668  43.666850777484896,-79.38114574756837
#
# [669 rows x 5 columns]

# %%
df.to_csv('bikestations_df.csv',index=False)
