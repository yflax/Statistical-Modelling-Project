# %% [markdown]
# Build a regression model.

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf

# %% [markdown]
# # first regression - linear regression one variable . Q: does being closer to restaurants cause a drop in bike usage resulting in a
# #higher number of available bikes? (weakness =results may not be very accurate bec. requested only one restaurant for each station - so can be many other restauratnst in station's vicinty)

# %%
import pandas as pd
import statsmodels.api as sm


# Create the design matrix X
X = combined_df['distance']
X = sm.add_constant(X)  # Add a constant term to the design matrix

# Create the target variable y
y = combined_df['available_bikes_x']

# Fit the OLS regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the summary statistics of the regression model
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      available_bikes_x   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1657
# Date:                Mon, 03 Jul 2023   Prob (F-statistic):              0.684
# Time:                        13:56:47   Log-Likelihood:                -1606.7
# No. Observations:                 500   AIC:                             3217.
# Df Residuals:                     498   BIC:                             3226.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.8374      0.705     12.528      0.000       7.451      10.223
# ...

# %% [markdown]
# combined_df contains two of each df - one for the yelp value and one for fsq
# closest_venues_df= contains all the clostest of the two values from both yelp and fsq ( need to add avialble bikes

# %%
#using merged_df and venue_type as categorical : bar or nor bar to analyze rltn b/w x vars and  available bikes

#loading merged_df 

import pandas as pd

merged_df = pd.read_csv('merged_df.csv')
df = merged_df.copy()
import pandas as pd
import statsmodels.api as sm

# Convert available_bikes column to integer type
df['available_bikes'] = df['available_bikes'].astype(int)

# Create is_bar column as boolean type
df['is_bar'] = df['venue_type_y'].str.contains('bar', case=False)

# Create x and y variables
x = df[['distance', 'rating', 'review_count', 'is_bar']]
y = df['available_bikes']
y = np.asarray(y)

# Convert is_bar column in x to int type
x.loc[:, 'is_bar'] = x['is_bar'].astype(int)


# Add constant to x
x = sm.add_constant(x)

# Fit the OLS model
model = sm.OLS(y, x)
results = model.fit()

# Print the summary statistics of the regression model
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     1.380
# Date:                Mon, 03 Jul 2023   Prob (F-statistic):              0.241
# Time:                        16:47:47   Log-Likelihood:                -800.60
# No. Observations:                 250   AIC:                             1611.
# Df Residuals:                     245   BIC:                             1629.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           35.9383     17.962      2.001      0.047       0.558      71.318
# ...

# %%
#cafe is better
#using merged_df and venue_type as categorical : cafe and  available bikes

#loading merged_df 

import pandas as pd

merged_df = pd.read_csv('merged_df.csv')
df = merged_df.copy()
import pandas as pd
import statsmodels.api as sm

# Convert available_bikes column to integer type
df['available_bikes'] = df['available_bikes'].astype(int)

# Create is_bar column as boolean type
df['is_cafe'] = df['venue_type_y'].str.contains('cafe', case=False)

# Create x and y variables
x = df[['distance', 'rating', 'review_count', 'is_cafe']]
y = df['available_bikes']
y = np.asarray(y)

# Convert is_bar column in x to int type
x.loc[:, 'is_cafe'] = x['is_cafe'].astype(int)


# Add constant to x
x = sm.add_constant(x)

# Fit the OLS model
model = sm.OLS(y, x)
results = model.fit()

# Print the summary statistics of the regression model
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     1.792
# Date:                Mon, 03 Jul 2023   Prob (F-statistic):              0.131
# Time:                        17:01:54   Log-Likelihood:                -799.78
# No. Observations:                 250   AIC:                             1610.
# Df Residuals:                     245   BIC:                             1627.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           28.5330     18.008      1.584      0.114      -6.937      64.003
# ...

# %%
#best fit yet 
#using merged_df and venue_type as categorical : iscafe and is bar 

#loading merged_df 

import pandas as pd

merged_df = pd.read_csv('merged_df.csv')
df = merged_df.copy()
import pandas as pd
import statsmodels.api as sm

# Convert available_bikes column to integer type
df['available_bikes'] = df['available_bikes'].astype(int)

# Create is_bar column as boolean type
df['is_cafe'] = df['venue_type_y'].str.contains('cafe', case=False)
df['is_bar'] = df['venue_type_y'].str.contains('bar',case=False)

# Create x and y variables
x = df[['distance', 'rating', 'review_count', 'is_cafe', 'is_bar']]
y = df['available_bikes']
y = np.asarray(y) #converting avial bikes to numerical 

# Convert is_bar column in x to int type
x.loc[:, 'is_cafe'] = x['is_cafe'].astype(int)
x.loc[:,'is_bar'] = x['is_bar'].astype(int)
                                               


# Add constant to x
x = sm.add_constant(x)

# Fit the OLS model
model = sm.OLS(y, x)
results = model.fit()

# Print the summary statistics of the regression model
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     1.769
# Date:                Mon, 03 Jul 2023   Prob (F-statistic):              0.120
# Time:                        17:05:44   Log-Likelihood:                -798.93
# No. Observations:                 250   AIC:                             1610.
# Df Residuals:                     244   BIC:                             1631.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           31.0068     18.086      1.714      0.088      -4.617      66.631
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create multivariate scatter plot with line of best fit
sns.pairplot(df, x_vars=['distance', 'rating', 'review_count', 'is_pizza', 'is_bar', 'is_Mexican', 'is_Vegetarian', 'is_Bakeries', 'is_Filipino', 'is_Indian'], y_vars='available_bikes', kind='reg')

# Set plot title
plt.suptitle('Multivariate Scatter Plot with Line of Best Fit', y=1.05)

# Adjust the layout of subplots
plt.tight_layout()

# Set the number of columns and rows for the subplots
num_cols = 3
num_rows = 4

# Get all the axes of the subplots
axes = plt.gcf().axes



# Display the plot
plt.show()

# %%
#best fit yet 
#using merged_df and venue_type as categorical : iscafe and is bar 

#loading merged_df 

import pandas as pd

merged_df = pd.read_csv('merged_df.csv')
df = merged_df.copy()
import pandas as pd
import statsmodels.api as sm

# Convert available_bikes column to integer type
df['available_bikes'] = df['available_bikes'].astype(int)

# Create is_bar column as boolean type
df['is_pizza'] = df['venue_type_y'].str.contains('pizza', case=False)
df['is_bar'] = df['venue_type_y'].str.contains('bar',case=False)
df['is_Mexican']=df['venue_type_y'].str.contains('Mexican',case=False)
# new types
df['is_Vegetarian'] = df['venue_type_y'].str.contains('vegetarian', case=False)
df['is_Bakeries'] = df['venue_type_y'].str.contains('bakeries', case=False)
df['is_Filipino'] = df['venue_type_y'].str.contains('filipino', case=False)
df['is_Indian'] = df['venue_type_y'].str.contains('indian', case=False)

x = df[['distance', 'rating', 'review_count', 'is_pizza', 'is_bar', 'is_Mexican', 'is_Vegetarian', 'is_Bakeries', 'is_Filipino', 'is_Indian']]
y = df['available_bikes']
y = np.asarray(y)  # converting available bikes to numerical #converting avial bikes to numerical 

# Convert is_bar column in x to int type
x.loc[:, 'is_pizza'] = x['is_pizza'].astype(int)
x.loc[:, 'is_bar'] = x['is_bar'].astype(int)
x.loc[:, 'is_Mexican'] = x['is_Mexican'].astype(int)
x.loc[:, 'is_Vegetarian'] = x['is_Vegetarian'].astype(int)
x.loc[:, 'is_Bakeries'] = x['is_Bakeries'].astype(int)
x.loc[:, 'is_Filipino'] = x['is_Filipino'].astype(int)
x.loc[:, 'is_Indian'] = x['is_Indian'].astype(int)







# Add constant to x
x = sm.add_constant(x)

# Fit the OLS model
model = sm.OLS(y, x)
results = model.fit()

# Print the summary statistics of the regression model
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.083
# Model:                            OLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     2.151
# Date:                Mon, 03 Jul 2023   Prob (F-statistic):             0.0215
# Time:                        17:17:03   Log-Likelihood:                -792.61
# No. Observations:                 250   AIC:                             1607.
# Df Residuals:                     239   BIC:                             1646.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            44.2812     18.979      2.333      0.020       6.893      81.669
# ...

# %%
#worse fit than w/ is_bar
#using merged_df without is_bar

#loading merged_df 

import pandas as pd

merged_df = pd.read_csv('merged_df.csv')
df = merged_df.copy()
import pandas as pd
import statsmodels.api as sm

# Convert available_bikes column to integer type
df['available_bikes'] = df['available_bikes'].astype(int)


# Create x and y variables
x = df[['distance', 'rating', 'review_count']]
y = df['available_bikes']
y = np.asarray(y)



# Add constant to x
x = sm.add_constant(x)

# Fit the OLS model
model = sm.OLS(y, x)
results = model.fit()

# Print the summary statistics of the regression model
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     1.403
# Date:                Mon, 03 Jul 2023   Prob (F-statistic):              0.242
# Time:                        16:58:36   Log-Likelihood:                -801.26
# No. Observations:                 250   AIC:                             1611.
# Df Residuals:                     246   BIC:                             1625.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           33.4776     17.843      1.876      0.062      -1.668      68.623
# ...

# %%
x=combined_df[['distance', 'venue_type',]]
x=pd.get_dummies(x,columns=['venue_type'])
x = sm.add_constant(x)

y=combined_df['available_bikes_x']

multivar= sm.OLS(y,x)
results = multivar.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      available_bikes_x   R-squared:                       0.259
# Model:                            OLS   Adj. R-squared:                  0.111
# Method:                 Least Squares   F-statistic:                     1.750
# Date:                Mon, 03 Jul 2023   Prob (F-statistic):           0.000208
# Time:                        16:20:15   Log-Likelihood:                -1531.9
# No. Observations:                 500   AIC:                             3232.
# Df Residuals:                     416   BIC:                             3586.
# Df Model:                          83
# Covariance Type:            nonrobust
# ...
#                                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Provide model output and an interpretation of the results.

# %% [markdown]
# # Stretch

# %% [markdown]
# How can you turn the regression model into a classification model?
